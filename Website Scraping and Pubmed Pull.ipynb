# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://med.stanford.edu/school/directory.html#faculty-labs"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')

# %%
all_links = soup.find_all('a', href = True)

# %%
import re
results = []
for link in all_links:
    text = BeautifulSoup(str(link), "lxml").get_text()
    url = link.get("href")
    if re.match('http:.*',url):
        results.append([text, url])

# %%
results
# Out:
# [['Adult-care doctor',
#   'http://stanfordhealthcare.org/content/shc/en/search-results.doctors.html'],
#  ['Pediatrician or pediatric specialist',
#   'http://www.stanfordchildrens.org/en/search/default?tab=doctors'],
#  ['Obstetrician',
#   'http://www.stanfordchildrens.org/en/search/default?tab=doctors&search-term=Obstetrics'],
#  ['Adult care',
#   'http://stanfordhealthcare.org/content/shc/en/search-results.clinics.html'],
#  ['Pediatric care', 'http://www.stanfordchildrens.org/en/service/index?'],
#  ['Obstetrics', 'http://www.stanfordchildrens.org/en/service/index?'],
#  ['Stanford Health Care',
#   'http://stanfordhealthcare.org/content/shc/en/search-results.clinics.html'],
#  ["Stanford Children's Health",
#   'http://www.stanfordchildrens.org/en/locations-directions'],
#  ['Emergency Department',
#   'http://stanfordhealthcare.org/medical-clinics/emergency-department.html'],
#  ['Lane Library', 'http://lane.stanford.edu/index.html'],
#  ['Make a gift online', 'http://pgnet.stanford.edu/goto/medgift'],
#  ['Ways to give', 'http://www.supportlpch.org/Waystogive'],
#  ['How your gift helps', 'http://www.supportlpch.org/page.aspx?pid=358'],
#  ['Make an online gift', 'http://www.supportlpch.org/donate'],
#  ['Stanford Health Care', 'http://stanfordhealthcare.org'],
#  ["Stanford Children's Health", 'http://www.stanfordchildrens.org'],
#  ['MD Program', 'http://med.stanford.edu/md/'],
#  ['Biosciences PhD Program', 'http://biosciences.stanford.edu/'],
#  ['Bioengineering PhD Programs',
#   'http://bioengineering.stanford.edu/academics/graduate-programs'],
#  ['',
#   'http://prevention.stanford.edu/education/coterminal-masters-of-science--m-s---in-community-health-and-pre.html'],
#  ['MS in Biomedical Informatics\xa0', 'http://bmi.stanford.edu/'],
#  ['MS in Community Health and Prevention Research',
#   'http://prevention.stanford.edu/education/coterminal-masters-of-science--m-s---in-community-health-and-pre.html'],
#  ['', 'http://med.stanford.edu/genetic-counseling/'],
#  ['MS in Epidemiology and Clinical Research',
#   'http://med.stanford.edu/epidemiology/'],
#  ['MS in Human Genetics and Genetic Counseling',
#   'http://med.stanford.edu/genetic-counseling/'],
#  ['MS in Health Services Research', 'http://med.stanford.edu/mshsr/'],
#  ['MS in Laboratory Animal Science',
#   'http://med.stanford.edu/compmed/mlas.html'],
#  ['MS in Medicine Program', 'http://msm.stanford.edu/'],
#  ['Pacific Graduate School of Psychology/Stanford University Doctor of Psychology Consortium\xa0 \n',
#   'http://psychiatry.stanford.edu/education/pgsp.html'],
#  ['Advanced Residency Training at Stanford', 'http://med.stanford.edu/arts/'],
#  ['Continuing Medical Education', 'http://cme.stanford.edu/'],
#  ['Residencies & Fellowships\n', 'http://gme.stanford.edu/'],
#  ['Office of Postdoctoral Affairs', 'http://postdocs.stanford.edu/'],
#  ['Stanford Clinical Neuroscience\xa0Immersion Experience',
#   'http://med.stanford.edu/psychiatry/special-initiatives/CNIX.html'],
#  ['Stanford EXPLORE Lecture Series for High School Students\n',
#   'http://explore.stanford.edu/'],
#  ['Stanford Institutes of Medicine Summer Research Program ',
#   'http://simr.stanford.edu/'],
#  [' Stanford Medical Youth Science Program ', 'http://smysp.stanford.edu/'],
#  ['Stanford Summer Research Program',
#   'http://bioengineering.stanford.edu/student-resources/reu'],
#  ['Biodesign', 'http://biodesign.stanford.edu'],
#  ['eCampus', 'http://ecampus.stanford.edu/'],
#  ['Stanford Cancer Imaging Training Program',
#   'http://scitprogram.stanford.edu/'],
#  ['Stanford Molecular Imaging Scholars program',
#   'http://smisprogram.stanford.edu/'],
#  ['Training in Biomedical Imaging Instrumentation\xa0',
#   'http://tbi2.stanford.edu/'],
#  ['Academic Advising',
#   'http://med.stanford.edu/md/academic-support/academic-advising.html'],
#  ['Alumni Association', 'http://med.stanford.edu/alumni/'],
#  ['Career Center', 'http://med.stanford.edu/careercenter/'],
#  ['Center for Innovation in Global Health',
#   'http://globalhealth.stanford.edu/'],
#  ['Course Catalog', 'http://medcatalog.stanford.edu/'],
#  ['Educational Programs and Services', 'http://med.stanford.edu/eps/'],
#  ['Center of Excellence in Diversity\xa0in Medical Education',
#   'http://coe.stanford.edu/'],
#  ['\xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0 \xa0\xa0\xa0 Faculty Development & Diversity',
#   'http://med.stanford.edu/facultydiversity/'],
#  ['Diversity in the PhD Programs',
#   'http://biosciences.stanford.edu/prospective/diversity/index.html'],
#  ['Diversity in Postdoctoral Training',
#   'http://postdocs.stanford.edu/prospects/diversity.html'],
#  ['Biosciences PhD Program',
#   'http://biosciences.stanford.edu/current/benefits/'],
#  ['MD Program', 'http://med.stanford.edu/md/financial-aid.html'],
#  ['Housing', 'http://www.stanford.edu/dept/rde/cgi-bin/drupal/housing/'],
#  ['Information Resources & Technology', 'http://med.stanford.edu/irt/'],
#  ['Lane Library', 'http://lane.stanford.edu/index.html'],
#  ['Student Commons', 'http://lksc.stanford.edu/students/'],
#  ['Academic Affairs', 'http://med.stanford.edu/academicaffairs/'],
#  ['Communication & Public Affairs', 'http://mednews.stanford.edu/'],
#  ['Conflict of Interest', 'http://med.stanford.edu/coi/'],
#  ['Faculty Development & Diversity\n',
#   'http://med.stanford.edu/facultydiversity/'],
#  ['Educational Programs & Services', 'http://med.stanford.edu/eps/'],
#  ['Department of Finance & Administration (DFA)\n',
#   'http://med.stanford.edu/financeadmin/'],
#  ['', 'http://hrg.stanford.edu/'],
#  ['Facilities Planning & Management', 'http://medfacilities.stanford.edu/'],
#  ['', 'http://hrg.stanford.edu/'],
#  ['Health & Safety', 'http://med.stanford.edu/somsafety/'],
#  ['Human Resources', 'http://hrg.stanford.edu/'],
#  ['Research Management Group', 'http://med.stanford.edu/rmg/'],
#  ['Center for Innovation in Global Health',
#   'http://globalhealth.stanford.edu/'],
#  ['Office of Government & Community Relations',
#   'http://med.stanford.edu/govrelations/'],
#  ['Information Resources & Technology', 'http://med.stanford.edu/irt/'],
#  ['Medical Center Development', 'http://med.stanford.edu/development/'],
#  ['Ombudsperson', 'http://med.stanford.edu/ombuds/'],
#  ['Faculty Senate', 'http://med.stanford.edu/senate/'],
#  ['Stanford Medicine Office of Emergency Management',
#   'http://med.stanford.edu/disaster/'],
#  ['Biochemistry', 'http://biochem.stanford.edu/'],
#  ['Genome Technology Center', 'http://med.stanford.edu/sgtc/'],
#  ['Bioengineering', 'http://bioengineering.stanford.edu/'],
#  ['Biomedical Data Sciences', 'http://med.stanford.edu/dbds.html'],
#  ['Biostatistics', 'http://med.stanford.edu/biostatistics/'],
#  ['Chemical & Systems Biology', 'http://chemsysbio.stanford.edu/'],
#  ['High-Throughput Bioscience Center', 'http://htbc.stanford.edu/'],
#  ['Comparative Medicine', 'http://med.stanford.edu/compmed/'],
#  ['Developmental Biology', 'http://devbio.stanford.edu/'],
#  ['Molecular and Genetic Medicine', 'http://cmgm.stanford.edu/'],
#  ['Genetics', 'http://genetics.stanford.edu/'],
#  ['Helix Group', 'http://helix-web.stanford.edu/'],
#  ['Genomic and Personalized Medicine (SCGPM)', 'http://scgpm.stanford.edu/'],
#  ['Health Research & Policy', 'http://hrp.stanford.edu/'],
#  ['Epidemiology', 'http://med.stanford.edu/epidemiology/'],
#  ['Health Services Research Division', 'http://med.stanford.edu/hsr/'],
#  ['Microbiology & Immunology', 'http://microimmuno.stanford.edu/'],
#  ['Proteomics Center', 'http://proteomics.stanford.edu/'],
#  ['Molecular and Cellular Physiology', 'http://mcp.stanford.edu/'],
#  ['Neurobiology', 'http://neurobiology.stanford.edu/'],
#  ['Structural Biology', 'http://structuralbio.stanford.edu/'],
#  ['Anesthesiology, Perioperative & Pain Medicine',
#   'http://med.stanford.edu/anesthesia/'],
#  ['Anesthesia Informatics and Media Lab', 'http://aim.stanford.edu/'],
#  ['Cardiac & Thoracic Anesthesia', 'http://med.stanford.edu/cardiacanes/'],
#  ['Critical Care Medicine\n', 'http://med.stanford.edu/criticalcare/'],
#  ['Pain Management Center', 'http://paincenter.stanford.edu/'],
#  ['Pediatric Anesthesia', 'http://pedsanesthesia.stanford.edu/'],
#  ['Cancer Institute', 'http://cancer.stanford.edu/'],
#  ['Dermatology', 'http://dermatology.stanford.edu/'],
#  ['Epithelial Biology', 'http://epibio.stanford.edu/'],
#  ['Emergency Medicine', 'http://emed.stanford.edu/'],
#  ['Medicine', 'http://medicine.stanford.edu/'],
#  ['Blood & Marrow Transplantation', 'http://bmt.stanford.edu/'],
#  ['Cardiovascular Medicine', 'http://cvmedicine.stanford.edu/'],
#  ['ADVANCE: Aatherosclerotic Disease Vascular Function and Genetic Epidemiology',
#   'http://med.stanford.edu/advance/'],
#  ['Center for Biomedical Informatics Research', 'http://bmir.stanford.edu/'],
#  ['Biomedical Informatics', 'http://bmi.stanford.edu/'],
#  ['Center for Primary Care and Outcomes Research',
#   'http://healthpolicy.stanford.edu/'],
#  ['Department of Medicine Resource Guide', 'http://domrg.stanford.edu/'],
#  ['Endocrinology', 'http://endocrinology.stanford.edu/'],
#  ['Gastroenterology & Hepatology', 'http://gastrohep.stanford.edu/'],
#  ['Grand Rounds', 'http://medicine.stanford.edu/events.html'],
#  ['Hematology', 'http://hematology.stanford.edu/'],
#  ['Hospice & Palliative Medicine', 'http://hospice.stanford.edu/'],
#  ['Hospital Medicine', 'http://med.stanford.edu/hospitalmedicine.html'],
#  ['Immunology & Rheumatology', 'http://immunology.stanford.edu/'],
#  ['Center for Clinical Immunology', 'http://ccis.stanford.edu/'],
#  ['Patient Education', 'http://patienteducation.stanford.edu/'],
#  ['Infectious Disease', 'http://med.stanford.edu/id/'],
#  ['Nephrology', 'http://med.stanford.edu/nephrology/'],
#  ['Oncology', 'http://oncology.stanford.edu/'],
#  ['Gynecology Oncology', 'http://obgyn.stanford.edu/divisions/gynonc.html'],
#  ['Primary Care and Population Health', 'http://med.stanford.edu/pcph.html'],
#  ['Pulmonary & Critical Care', 'http://pulmonary.stanford.edu/'],
#  ['The\xa0Sean N. Parker Center for Allergy and Asthma Research',
#   'http://med.stanford.edu/allergyandasthma.html'],
#  ['Vera Moulton Wall Center', 'http://wallcenter.stanford.edu/'],
#  ['Residency Program', 'http://medicine.stanford.edu/residency.html'],
#  ['Stanford Prevention Research Center', 'http://prevention.stanford.edu/'],
#  ['Health Improvement', 'http://hip.stanford.edu/'],
#  ['Memory Disorders', 'http://scmd.stanford.edu'],
#  ['Neurosurgery', 'http://neurosurgery.stanford.edu/'],
#  ['Center for Compassion and Altruism', 'http://ccare.stanford.edu'],
#  ['Epilepsy',
#   'http://med.stanford.edu/neurosurgery/divisions/epilepsy.html  '],
#  ['Essential Tremor',
#   'http://med.stanford.edu/neurosurgery/divisions/EssentialTremor.html'],
#  ['Functional Neurosurgery',
#   'http://med.stanford.edu/neurosurgery/divisions/functional.html  '],
#  ['Global Health Neurosurgery',
#   'http://med.stanford.edu/neurosurgery/divisions/globalhealth.html'],
#  ['Head and Spine Trauma',
#   'http://stanfordhealthcare.org/medical-clinics/neurological-spine-disorders-clinic'],
#  ['Moyamoya', 'http://med.stanford.edu/neurosurgery/divisions/moyamoya.html'],
#  ['Neurogenetics',
#   'http://med.stanford.edu/neurosurgery/divisions/neurogenetics.html'],
#  ['Pain', 'http://med.stanford.edu/neurosurgery/divisions/pain.html'],
#  ['Pediatric Neurosurgery',
#   'http://med.stanford.edu/neurosurgery/divisions/pediatric.html  '],
#  ['Peripheral Nerve Surgery',
#   'http://med.stanford.edu/neurosurgery/divisions/peripheralnerve.html'],
#  ['Pituitary Center',
#   'http://med.stanford.edu/neurosurgery/divisions/pituitary.html'],
#  ['Spine Surgery',
#   'http://med.stanford.edu/neurosurgery/divisions/neurospine.html'],
#  ['Stanford Brain Metastases Consortium',
#   'http://med.stanford.edu/neurosurgery/divisions/brain-metastases-consortium.html'],
#  ['Stanford Stroke Center',
#   'http://med.stanford.edu/neurology/divisions/stroke.html'],
#  ['Virtual Reality',
#   'http://med.stanford.edu/neurosurgery/divisions/vr-lab.html'],
#  ['Obstetrics & Gynecology', 'http://obgyn.stanford.edu/'],
#  ['Family Planning Services and Research',
#   'http://obgyn.stanford.edu/divisions/family_planning.html'],
#  ['General Gynecology and Urology',
#   'http://obgyn.stanford.edu/divisions/gyn.html'],
#  ['General OB', 'http://obgyn.stanford.edu/divisions/obstetrics.html'],
#  ['Maternal - Fetal Medicine', 'http://obgyn.stanford.edu/divisions/mfm.html'],
#  ['OB/GYN Residents', 'http://obgynresidents.stanford.edu/'],
#  ['Reproductive Biology',
#   'http://obgyn.stanford.edu/divisions/reproductive_bio.html'],
#  ['Reproductive Endocrinology and Infertility',
#   'http://obgyn.stanford.edu/divisions/rei.html'],
#  ['Women & Sex Differences in Medicine', 'http://wsdm.stanford.edu/'],
#  ['Ophthalmology', 'http://ophthalmology.stanford.edu/'],
#  ['Orthopaedic Surgery', 'http://ortho.stanford.edu/'],
#  ['Otolaryngology', 'http://med.stanford.edu/ohns/'],
#  ['Hearing Loss', 'http://hearinglosscure.stanford.edu/'],
#  ['Hearing Loss Blog', 'http://hearinglosscure.stanford.edu/blog/'],
#  ['Residents', 'http://med.stanford.edu/ohns/education/residency/portal/'],
#  ['Pathology', 'http://pathology.stanford.edu/'],
#  ['Diagnostic Services',
#   'http://pathology.stanford.edu/patient/services.html'],
#  ['Autopsy', 'http://autopsy.stanford.edu/'],
#  ['Clinical Biochemical Genetics', 'http://biochemgenetics.stanford.edu/'],
#  ['Clinical Chemistry', 'http://clinicalchemistry.stanford.edu/'],
#  ['Clinical Microbiology', 'http://clinicalmicrobiology.stanford.edu/'],
#  ['Clinical Virology', 'http://clinicalvirology.stanford.edu/'],
#  ['Cytogenetics', 'http://cytogenetics.stanford.edu/'],
#  ['Cytopathology', 'http://cytopathology.stanford.edu/'],
#  ['Dermatopathology Service', 'http://dermatopathology.stanford.edu/'],
#  ['Hematopathology', 'http://hematopathology.stanford.edu/'],
#  ['Immunodiagnosis', 'http://immunodiagnosis.stanford.edu/'],
#  ['Molecular Genetic Pathology', 'http://moleculargenetics.stanford.edu/'],
#  ['Neuropathology', 'http://neuropathology.stanford.edu/'],
#  ['Renal Pathology', 'http://renalpathology.stanford.edu/'],
#  ['Surgical Pathology', 'http://surgicalpathology.stanford.edu/'],
#  ['Transfusion Medicine', 'http://transfusionmedicine.stanford.edu/'],
#  ['Research Laboratories', 'http://pathology.stanford.edu/research/labs.html'],
#  ['Pediatrics', 'http://pediatrics.stanford.edu/'],
#  ['Adolescent Medicine', 'http://adolescent.stanford.edu/'],
#  ['Cardiology', 'http://pedcard.stanford.edu/'],
#  ['Spectrum Child Health', 'http://spectrumchildhealth.stanford.edu/'],
#  ['Critical Care', 'http://pedcriticalcare.stanford.edu/'],
#  ['Endocrinology and Diabetes', 'http://dped.stanford.edu/'],
#  ['Gastroenterology', 'http://med.stanford.edu/gastroenterology/'],
#  ['General Pediatrics', 'http://genpeds.stanford.edu/'],
#  ['Hematology & Oncology', 'http://pedhemonc.stanford.edu/'],
#  ['Human Gene Therapy', 'http://med.stanford.edu/genetherapy/'],
#  ['Immunology & Allergy', 'http://pedimmunology.stanford.edu/'],
#  ['Infectious Diseases', 'http://med.stanford.edu/pedsid/'],
#  ['Medical Genetics', 'http://medicalgenetics.stanford.edu/'],
#  ['Neonatal & Developmental Medicine', 'http://neonatology.stanford.edu/'],
#  ['Nephrology', 'http://pednephrology.stanford.edu/'],
#  ['Pulmonary Medicine', 'http://pedpulmonary.stanford.edu/'],
#  ['Residency Training Program', 'http://med.stanford.edu/pedsres/'],
#  ['Rheumatology', 'http://pedrheumatology.stanford.edu/'],
#  ['Systems Medicine', 'http://systemsmedicine.stanford.edu/'],
#  ['Vera Moulon Wall Center', 'http://wallcenter.stanford.edu/'],
#  ['Psychiatry & Behavioral Sciences', 'http://psychiatry.stanford.edu/'],
#  ['Bipolar Disorders Clinics', 'http://bipolar.stanford.edu/'],
#  ['Stanford Center for Sleep Sciences & Medicine',
#   'http://med.stanford.edu/sleepdivision.html'],
#  ['Center for Interdisciplinary Brain Sciences Research',
#   'http://cibsr.stanford.edu/'],
#  ['Sleep and Circadian Neurobiology Lab',
#   'http://circadian.stanford.edu/index.html'],
#  ['Center for Narcolepsy', 'http://psychiatry.stanford.edu/narcolepsy/'],
#  ["Center for Neuroscience in Women's Health",
#   'http://womensneuroscience.stanford.edu/'],
#  ['Center on Stress & Health', 'http://stresshealthcenter.stanford.edu/'],
#  ['Child and Adolescent Psychiatry', 'http://childpsychiatry.stanford.edu/'],
#  ['Stanford Early Life Stress Research Program',
#   'http://med.stanford.edu/elspap/'],
#  ['Stanford Pediatric Bipolar Disorders Program',
#   'http://pediatricbipolar.stanford.edu/'],
#  ['Depression Research Clinic', 'http://drc.stanford.edu/'],
#  ['Eating Disorders Research Program', 'http://edresearch.stanford.edu/'],
#  ['Sleep Health and Insomnia Program', 'http://insomnia.stanford.edu/'],
#  ['Laboratory for the Study of Behavioral Medicine',
#   'http://bml.stanford.edu/'],
#  ['Obsessive Compulsive & Related Disorders Research Program',
#   'http://ocd.stanford.edu/'],
#  ['Stanford/VA Aging Clinical Research Center',
#   'http://psychiatry.stanford.edu/alzheimer/'],
#  ["Stanford/VA Alzheimer's Clinical Research Center",
#   'http://svalz.stanford.edu/'],
#  ['Prodrome and Early Psychosis Program Network (PEPPNET)',
#   'http://med.stanford.edu/peppnet.html'],
#  ['Pediatric Mood Disorders Program', 'http://med.stanford.edu/pedmood.html'],
#  ['Radiation Oncology', 'http://radonc.stanford.edu/'],
#  ['Radiation & Cancer Biology', 'http://med.stanford.edu/radcancerbio/'],
#  ['Radiology', 'http://radiology.stanford.edu/'],
#  ['Interventional Radiology', 'http://interventionalradiology.stanford.edu/'],
#  ['Nuclear Medicine', 'http://nuclearmedicine.stanford.edu/'],
#  ['3D and Quantitative Imaging', 'http://3dradiology.stanford.edu/'],
#  ['Pediatric Radiology', 'http://pedrad.stanford.edu/'],
#  ['Surgery', 'http://surgery.stanford.edu/'],
#  ['Clinical Anatomy', 'http://med.stanford.edu/anatomy/'],
#  ['General Surgery', 'http://med.stanford.edu/gensurg/'],
#  ['Asian Liver Center', 'http://liver.stanford.edu/'],
#  ['Bariatric Surgery',
#   'http://stanfordhospital.org/clinicsmedServices/COE/surgicalServices/generalSurgery/bariatricsurgery/'],
#  ['Colon & Rectal Surgery', 'http://cancer.stanford.edu/surgery/colorectal/'],
#  ['Scalpel: Residents', 'http://scalpel.stanford.edu/'],
#  ['Surgical Oncology', 'http://cancer.stanford.edu/patient_care/ourTeam.html'],
#  ['Trauma/Critical Care Surgery',
#   'http://stanfordhospital.org/clinicsmedServices/medicalServices/emergency/trauma/index.html'],
#  ['Pediatric General Surgery',
#   'http://www.stanfordchildrens.org/en/service/general-surgery'],
#  ['Plastic & Reconstructive Surgery', 'http://plasticsurgery.stanford.edu/'],
#  ['Hand Surgery', 'http://handsurgery.stanford.edu/'],
#  ['Multi-Organ Transplantation',
#   'http://stanfordhospital.org/clinicsmedServices/COE/transplant/'],
#  ['Abdominal Transplantation', 'http://transplantation.stanford.edu/'],
#  ['Adult Kidney and Kidney/Pancreas Transplantation',
#   'http://stanfordhospital.org/clinicsmedServices/COE/transplant/kidney/'],
#  ['Liver Transplant Program',
#   'http://stanfordhospital.org/clinicsmedServices/COE/transplant/liver/'],
#  ['Transplant Immunobiology Laboratory', 'http://www.stanford.edu/group/TIL/'],
#  ['Vascular Surgery', 'http://vascular.stanford.edu/'],
#  ['Urology', 'http://urology.stanford.edu/'],
#  ['American Parkinson Disease Association Information & Referral Center',
#   'http://parkinsons.stanford.edu/'],
#  ['Cardinal Free Clinics', 'http://cfc.stanford.edu/'],
#  ['Child Abuse Prevention', 'http://childabuse.stanford.edu/'],
#  ['Domestic Abuse Prevention', 'http://domesticabuse.stanford.edu/'],
#  ['Elder Abuse Prevention', 'http://elderabuse.stanford.edu/'],
#  ['Health and Resource Initiative for Veterans Everywhere',
#   'http://ruralhealth.stanford.edu/'],
#  ['Health Improvement Program', 'http://hip.stanford.edu/'],
#  ['Human Trafficking', 'http://humantraffickingmed.stanford.edu/'],
#  ['Living Strong Living Well Program', 'http://lslw.stanford.edu/'],
#  ['Mini Med School', 'http://med.stanford.edu/minimed/'],
#  ['Newborn Nursery at LPCH', 'http://newborns.stanford.edu/'],
#  ['Office of Community Health\xa0', 'http://och.stanford.edu'],
#  ['Pediatric Advocacy Program', 'http://pedsadvocacy.stanford.edu'],
#  ['Psychiatric Medications for Young People', 'http://whatmeds.stanford.edu/'],
#  ['Stanford Health Library', 'http://healthlibrary.stanford.edu/'],
#  ['Stanford Health Promotion Network\xa0', 'http://shpn.stanford.edu/'],
#  ['Teen Services', 'http://teen.stanford.edu/'],
#  ['Biomaterials & Advanced Drug Delivery Center',
#   'http://bioadd.stanford.edu/'],
#  ['Cell Sciences Imaging Facility', 'http://microscopy.stanford.edu/'],
#  ['Center for Neuroscience Research Cores',
#   'http://med.stanford.edu/neuroresearchcores/'],
#  ['Computational Services & Bioinformatics Facility',
#   'http://cmgm.stanford.edu/'],
#  ['Data Coordinating Center', 'http://med.stanford.edu/dcc/'],
#  ['Fluorescence Activated Cell Sorting Facility', 'http://facs.stanford.edu/'],
#  ['Fly Facility', 'http://flycenter.stanford.edu/'],
#  ['Genetics Bioinformatics Service Center', 'http://gbsc.stanford.edu/'],
#  ['Gene Vector Virus Center', 'http://med.stanford.edu/gvvc/'],
#  ['Genome (Sequencing) Service Center', 'http://mendel.stanford.edu/SSC/'],
#  ['Hematopathology Consult Services', 'http://hematopathology.stanford.edu/'],
#  ['High Throughput Bioscience Center', 'http://htbc.stanford.edu/'],
#  ['Human Immune Monitoring Center', 'http://himc.stanford.edu/'],
#  ['Otolaryngology Imaging Core', 'http://otolic.stanford.edu/'],
#  ['Neuroscience Microscopy Service', 'http://nisms.stanford.edu/'],
#  ['Protein & Nucleic Acid Facility', 'http://pan.stanford.edu/'],
#  ['Richard M. Lucas Center for Imaging', 'http://rsl.stanford.edu/lucas/'],
#  ['Stanford Behavioral & Functional Neuroscience Laboratory',
#   'http://sbfnl.stanford.edu/'],
#  ['Stanford Functional Genomics Facility', 'http://www.microarray.org/sfgf/'],
#  ['Stanford Immunodiagnosis Service', 'http://immunodiagnosis.stanford.edu/'],
#  ['Stanford Magnetic Resonance Laboratory', 'http://smrl.stanford.edu/'],
#  ['Stanford Murine Phenotyping Core', 'http://murinecvcore.stanford.edu/'],
#  ['Stanford Surgical Pathology Service',
#   'http://surgicalpathology.stanford.edu/'],
#  ['Stanford Tissue Bank', 'http://tissuebank.stanford.edu/'],
#  ['Stanford Transfusion Service', 'http://transfusionmedicine.stanford.edu/'],
#  ['Surgical Pathology Criteria', 'http://surgpathcriteria.stanford.edu/'],
#  ['Transgenic, Knockout & Tumor Model Center',
#   'http://med.stanford.edu/transgenic/'],
#  ['Transgenic Research Center', 'http://med.stanford.edu/transgenic/'],
#  ['Translational Applications Service Center', 'http://tasc.stanford.edu/'],
#  ['Veterinary Service Center\xa0', 'http://vsc.stanford.edu/'],
#  ['Alizadeh, Ash', 'http://med.stanford.edu/labs/ash_alizadeh/'],
#  ['Altman, Russ', 'http://www-helix.stanford.edu/people/altman/'],
#  ['Alvira, Christina', 'http://alviralab.stanford.edu/'],
#  ['Andreasson, Katrin', 'http://neurology.stanford.edu/labs/andreassonlab/'],
#  ['Artandi, Steven',
#   'http://hematology.stanford.edu/research/labs/artandi.html'],
#  ['Ashley, Euan', 'http://ashleylab.stanford.edu'],
#  ['Bendavid, Eran', 'http://bendavid.stanford.edu/'],
#  ['Benjamin, Latanya', 'http://lbpedsderm.stanford.edu'],
#  ['Bernert, Rebecca', 'http://bernertlab.stanford.edu'],
#  ['Bernstein, Daniel', 'http://murinecvcore.stanford.edu'],
#  ['Bhutani, Nidhi', 'http://bhutanilab.stanford.edu'],
#  ['Blau, Helen M.', 'http://www.stanford.edu/group/blau/'],
#  ['Block, Steven', 'http://www.stanford.edu/group/blocklab/'],
#  ['Bogyo, Matthew', 'http://bogyolab.stanford.edu'],
#  ['Boothroyd, John', 'http://boothroydlab.stanford.edu/'],
#  ['Boxer, Linda', 'http://hematology.stanford.edu/research/boxer_lab.html'],
#  ['Bronte-Stewart, Helen M.',
#   'http://neurology.stanford.edu/labs/bronte-stewartlab/'],
#  ['Brown, Pat', 'http://brownlab.stanford.edu/'],
#  ['Brunet, Anne', 'http://www.stanford.edu/group/brunet/'],
#  ['Brunger, Axel', 'http://atb.slac.stanford.edu'],
#  ['Brutlag, Douglas L.', 'http://brutlag.stanford.edu'],
#  ['Buckwalter, Marion S.', 'http://buckwalter.stanford.edu/'],
#  ['Bustamante, Carlos D.', 'http://bustamantelab.stanford.edu/'],
#  ['Butcher, Eugene C.', 'http://butcherlab.stanford.edu'],
#  ['Butte, Manish', 'http://tcell.stanford.edu/'],
#  ['Calos, Michele P.', 'http://www.stanford.edu/~calos/'],
#  ['Camarillo, David', 'http://camlab.stanford.edu/'],
#  ['Chang, Anne', 'http://annechangmd.stanford.edu/'],
#  ['Chang, Howard Y.', 'http://changlab.stanford.edu'],
#  ['Chen, James', 'http://chen.stanford.edu'],
#  ['Cheng, Zhen', 'http://chenglab.stanford.edu'],
#  ['Chu, Gil', 'http://cmgm.stanford.edu/~chu/'],
#  ['Chu, Larry', 'http://painresearch.stanford.edu/'],
#  ['Cleary, Michael', 'http://www.stanford.edu/group/cleary/'],
#  ['Clinical Chemistry Labatory', 'http://clinicalchemistry.stanford.edu/'],
#  ['Clinical Microbiology Laboratory',
#   'http://clinicalmicrobiology.stanford.edu/'],
#  ['Clinical Virology', 'http://clinicalvirology.stanford.edu/'],
#  ['Cognitive and Systems Neuroscience Laboratory\xa0',
#   'http://scsnl.stanford.edu/'],
#  ['Cohen, Harvey', 'http://med.stanford.edu/labs/harvey_cohen/'],
#  ['Cohen, Stanley N.', 'http://sncohenlab.stanford.edu'],
#  ['Constantinou, Chris', 'http://med.stanford.edu/constantinou/'],
#  ['Contag, Christopher', 'http://mips.stanford.edu/research/mbil.html'],
#  ['Crabtree, Gerald R.', 'http://crablab.stanford.edu'],
#  ['Cytogenetics Laboratory', 'http://cytogenetics.stanford.edu/'],
#  ['Cytopathology Laboratory', 'http://cytopathology.stanford.edu/'],
#  ['Daldrup-Link, Heike', 'http://daldrup-link-lab.stanford.edu/'],
#  ['Dalman, Ron', 'http://vascular.stanford.edu/research/labs/dalmanlab.html'],
#  ['Davis, Mark', 'http://cmgm.stanford.edu/hhmi/mdavis/'],
#  ['Day, John W.', 'http://neurology.stanford.edu/labs/daylab/'],
#  ['de Lecea, Luis', 'http://delecea.stanford.edu'],
#  ['Dermatopathology Service', 'http://dermatopathology.stanford.edu/'],
#  ['Diehn, Maximillan', 'http://med.stanford.edu/diehnlab/'],
#  ['Dirbas, Federick M.', 'http://dirbas.stanford.edu/'],
#  ['Dolmetsch, Richardo', 'http://dolmetschlab.stanford.edu/'],
#  ['Drover, David', 'http://med.stanford.edu/anesthesia/research/drover.html'],
#  ['Einav, Shirit', 'http://med.stanford.edu/einavlab/main.html'],
#  ['Etkin, Amit', 'http://etkinlab.stanford.edu/'],
#  ['Fahrig, Rebecca', 'http://zeegolab.stanford.edu/'],
#  ['Fathman, C Garrison', 'http://fathmanlab.stanford.edu/'],
#  ['Feldman, Brian', 'http://feldmanlab.stanford.edu/'],
#  ['Felsher, Dean', 'http://med.stanford.edu/labs/dean_felsher/'],
#  ['Fernald, Russell', 'http://www.stanford.edu/group/fernaldlab/'],
#  ['Ferrell, James E.', 'http://www.stanford.edu/group/ferrelllab/'],
#  ['Fire, Andrew', 'http://firelab.stanford.edu/'],
#  ['Ford, James', 'http://jamesfordlab.stanford.edu'],
#  ['Fries, James', 'http://aramis.stanford.edu'],
#  ['Gallagher-Thompson, Dolores', 'http://www.stanford.edu/~dolorest/'],
#  ['Galli, Stephen J.', 'http://gallilab.stanford.edu/'],
#  ['Garcia, K. Christopher', 'http://garcia-lab.stanford.edu/Welcome.html'],
#  ['Garner, Craig', 'http://garnerlab.stanford.edu/'],
#  ['George, Paul', 'http://med.stanford.edu/george-lab.html  '],
#  ['Gephart, Melanie', 'http://www.gephartlab.com'],
#  ['Giaccia, Amato', 'http://giaccialab.stanford.edu/'],
#  ['Giffard, Rona G.', 'http://med.stanford.edu/giffardlab/'],
#  ['Glenn, Jeffrey S.', 'http://glennlab.stanford.edu/'],
#  ['Glover, Gary H.', 'http://rsl.stanford.edu/glover/'],
#  ['Goodman, Miriam', 'http://wormsense.stanford.edu/'],
#  ['Goronzy, Jörg J.', 'http://goronzylab.stanford.edu/'],
#  ['Graef, Isabella', 'http://graeflab.stanford.edu/'],
#  ['Graves, Edward', 'http://graveslab.stanford.edu/'],
#  ['Greenberg, Peter',
#   'http://hematology.stanford.edu/research/labs/greenberg.html'],
#  ['Greicius, Michael', 'http://findlab.stanford.edu'],
#  ['Han, May', 'http://neurology.stanford.edu/labs/hanlab/'],
#  ['Harbury, Pehr A.B.', 'http://cmgm.stanford.edu/biochem/harbury/'],
#  ['Hargreaves, Brian', 'http://med.stanford.edu/bmrgroup.html'],
#  ['Hastie, Trevor', 'http://www.stanford.edu/~hastie/'],
#  ['Heller, Stefan', 'http://hellerlab.stanford.edu/'],
#  ['Henderson, Victor', 'http://neurology.stanford.edu/labs/hendersonlab/'],
#  ['Herschlag, Dan', 'http://cmgm.stanford.edu/biochem/herschlag/'],
#  ['Herzenberg, Len and Lee', 'http://www.herzenberglab.org'],
#  ['Hestrin, Shaul', 'http://www.stanford.edu/~shestrin/'],
#  ['Hoffman, Andrew R.', 'http://hoffmanlab.stanford.edu/'],
#  ['Hristov, Dimitre', 'http://hristovlab.stanford.edu/'],
#  ['Hsieh, Michael', 'http://uti.stanford.edu/'],
#  ['Huang, Ngan F.', 'http://huanglab.stanford.edu/'],
#  ['Huang, Ting-Ting', 'http://neurology.stanford.edu/labs/huanglab/'],
#  ['Huguenard, John', 'http://huguenardlab.stanford.edu'],
#  ['Human Pain Research Laboratory', 'http://painlab.stanford.edu/'],
#  ['Jackson, Peter', 'http://baxterlab.stanford.edu/'],
#  ['Jacobs, Charlotte DeCroes',
#   'http://med.stanford.edu/labs/charlotte_jacobs/'],
#  ['Jeffrey, Stefanie S.', 'http://www.stanford.edu/group/sjeffreylab/'],
#  ['Ji, Hanlee', 'http://dna-discovery.stanford.edu/'],
#  ['Katzenstein, David A.', 'http://med.stanford.edu/act-now/'],
#  ['Kay, Mark A.', 'http://kaylab.stanford.edu/'],
#  ['Kesler, Shelli', 'http://nnl.stanford.edu/'],
#  ['Khavari, Paul', 'http://khavarilab.stanford.edu/'],
#  ['Kim, Stuart', 'http://cmgm.stanford.edu/~kimlab/'],
#  ['Kingsley, David M.', 'http://kingsley.stanford.edu'],
#  ['Kirkegaard, Karla', 'http://www.stanford.edu/group/kirkegaard/'],
#  ['Kobilka, Brian', 'http://kobilkalab.stanford.edu/'],
#  ['Koong, Albert', 'http://med.stanford.edu/koonglab.html'],
#  ['Kopito, Ron R.',
#   'http://www.stanford.edu/group/kopito/Kopito_Lab/Home.html'],
#  ['Kornberg, Roger', 'http://kornberg.stanford.edu/'],
#  ['Krams, Sheri M.', 'http://www.stanford.edu/group/TIL/'],
#  ['Krasnow, Mark', 'http://cmgm.stanford.edu/krasnow/'],
#  ['Kuo, Calvin', 'http://kuolab.stanford.edu/'],
#  ['Lee, Jin Hyung', 'http://llab.stanford.edu/'],
#  ['Leeper, Nick', 'http://med.stanford.edu/leeperlab/'],
#  ['Leppert, John', 'http://leppertlab.stanford.edu/'],
#  ['Leung, Lawrence Lit King',
#   'http://hematology.stanford.edu/research/labs/leung.html'],
#  ['Levin, Chris', 'http://miil.stanford.edu'],
#  ['Levinson, Douglas F.', 'http://depressiongenetics.stanford.edu/'],
#  ['Levy, Ronald', 'http://med.stanford.edu/labs/ronald_levy/'],
#  ['Levy, Shoshana', 'http://med.stanford.edu/labs/shoshana_levy/'],
#  ['Lewis, David B.', 'http://dblewislab.stanford.edu/'],
#  ['Li, Billy Li', 'http://med.stanford.edu/lilab/'],
#  ['Liao, Joseph C.', 'http://www.stanford.edu/group/liaolab/'],
#  ['Lin, Michael Z.', 'http://linlab.stanford.edu/'],
#  ['Lipsick, Joe', 'http://www.stanford.edu/group/lipsick/'],
#  ['Longo, Frank M.', 'http://neurology.stanford.edu/labs/longolab/'],
#  ['MacIver, M. Bruce', 'http://www.stanford.edu/group/maciverlab/'],
#  ['Mackey, Sean', 'http://snapl.stanford.edu'],
#  ['Maduke, Merritt', 'http://maduke.stanford.edu'],
#  ['Majeti, Ravi', 'http://majetilab.stanford.edu/'],
#  ['Malenka, Robert C.', 'http://malenkalab.stanford.edu/'],
#  ['Marinkovich, Peter', 'http://bmz.stanford.edu/'],
#  ['Matin, A.C.',
#   'http://www.stanford.edu/~amatin/MatinLabHomePage/MatinLabHome-Page.htm'],
#  ['McConnell, Susan K.', 'http://www.stanford.edu/group/skmlab/'],
#  ['McMahan, Uel', 'http://mcmahan.stanford.edu'],
#  ['McNab, Jennifer', 'http://med.stanford.edu/mcnablab/'],
#  ['Merigan, Thomas', 'http://www.stanford.edu/%7Emerigan/'],
#  ['Meyer, Tobias', 'http://www.stanford.edu/group/meyerlab/'],
#  ['Mignot, Emmanuel', 'http://psychiatry.stanford.edu/narcolepsy/mignot.html'],
#  ['Mocarski, Edward', 'http://cmgm.stanford.edu/micro/fac/mocarski.html'],
#  ['Mochley-Rosen, Daria', 'http://www.stanford.edu/group/mochly-rosen/'],
#  ['Molecular Genetic Pathology at Stanford',
#   'http://moleculargenetics.stanford.edu/'],
#  ['Monack, Denise', 'http://monacklab.stanford.edu/'],
#  ['Monje, Michelle', 'http://neurology.stanford.edu/labs/monjelab/'],
#  ['Montgomery, Stephen', 'http://montgomerylab.stanford.edu/'],
#  ['Moseley, Michael', 'http://rsl.stanford.edu/moseley/'],
#  ['Nadeau, Kari', 'http://nadeaulab.stanford.edu/'],
#  ['Nelson, W James', 'http://nelsonlab.stanford.edu/'],
#  ['Neural Prosthetics Translational Laboratory',
#   'http://sites.stanford.edu/nptl'],
#  ['Newsome, William', 'http://monkeybiz.stanford.edu'],
#  ['Nicolls, Mark', 'http://nicollslab.stanford.edu/'],
#  ['Nishino, Seilji', 'http://circadian.stanford.edu/'],
#  ['Nolan Garry P.', 'http://baxterlab.stanford.edu/'],
#  ['Nolan, Gary', 'http://www.stanford.edu/group/nolan/'],
#  ['Nusse, Roel', 'http://www.stanford.edu/group/nusselab/cgi-bin/lab/main'],
#  ["O'Hara, Ruth", 'http://llandlab.stanford.edu/'],
#  ['Oghalai, John S.', 'http://oghalailab.stanford.edu/'],
#  ['Oro, Anthony', 'http://orolab.stanford.edu'],
#  ['Palanker, Daniel', 'http://www.stanford.edu/~palanker/lab/'],
#  ['Pande, Vijay', 'http://folding.stanford.edu'],
#  ['Parker, Karen J.', 'http://parkerlab.stanford.edu/'],
#  ['Parsonnet, Julie', 'http://parsonnet.stanford.edu/'],
#  ['Parvizi, Josef', 'http://neurology.stanford.edu/labs/parvizilab/'],
#  ['Pauly, Kim Butts', 'http://kbplab.stanford.edu/'],
#  ['Peltz, Gary', 'http://med.stanford.edu/peltzlab/'],
#  ['Penn, Anna', 'http://pennlab.stanford.edu/'],
#  ['Perkins, David', 'http://www.stanford.edu/group/neurospora/'],
#  ['Pfeffer, Suzanne', 'http://pfeffer.stanford.edu'],
#  ['Plevritis, Sylvia', 'http://plevritis.stanford.edu/'],
#  ['Pollack, Jonathan', 'http://pollacklab.stanford.edu/'],
#  ['Porteus, Matthew', 'http://porteuslab.stanford.edu'],
#  ['Poston, Kathleen', 'http://neurology.stanford.edu/labs/postonlab/'],
#  ['Pratx, Guillem', 'http://med.stanford.edu/pratxlab/'],
#  ['Prince, David', 'http://neurology.stanford.edu/labs/princelab/'],
#  ['Pritzker, Nancy Friend', 'http://pritzkerlab.stanford.edu/'],
#  ['Puglisi, Joseph', 'http://puglisi.stanford.edu'],
#  ['Qi, Stanley', 'http://med.stanford.edu/qilab/'],
#  ['Quake, Stephen', 'http://thebigone.stanford.edu'],
#  ['Quertermous, Thomas', 'http://quertermous.stanford.edu/'],
#  ['Rabinovitch, Marlene and Bland, Richard',
#   'http://med.stanford.edu/labs/rabinovitchbland/'],
#  ['Radioimmunotherapy (RIT)', 'http://www.stanford.edu/group/RIT/'],
#  ['Rajadas, Jayakumar', 'http://bioadd.stanford.edu/'],
#  ['Rando, Thomas', 'http://randolab.stanford.edu'],
#  ['Rao, Jianghong', 'http://raolab.stanford.edu/'],
#  ['Raymond, Jennifer', 'http://raymondlab.stanford.edu'],
#  ['Reimer, Rich', 'http://www.stanford.edu/~rjreimer/'],
#  ['Robinson, Bill', 'http://robinsonlab.stanford.edu'],
#  ['Robinson, Terry', 'http://terryrobinsonlab.stanford.edu'],
#  ['Rohatgi, Rajat', 'http://rohatgilab.stanford.edu/'],
#  ['Rudd, Peter', 'http://www.stanford.edu/~rudd/'],
#  ['Ruiz-Lozano, P', 'http://med.stanford.edu/ruizlozanolab/'],
#  ['Rutt, Brian', 'http://rsl.stanford.edu/rutt/'],
#  ['Saccharomyces Genome Database (SGD)', 'http://www.yeastgenome.org'],
#  ['Sage, Julien', 'http://www.stanford.edu/group/sage/'],
#  ['Sarnow, Peter', 'http://cmgm.stanford.edu/micro/sarnow_lab/'],
#  ['Scott, Matthew', 'http://med.stanford.edu/labs/matthew_scott/'],
#  ['Seung, K. Kim', 'http://seungkimlab.stanford.edu'],
#  ['Shah, Nigam', 'http://shahlab.stanford.edu'],
#  ['Shatz, Carla', 'http://www.stanford.edu/group/shatzlab/'],
#  ['Sherlock, Gavin', 'http://www.stanford.edu/group/sherlocklab/'],
#  ['Sibley, Eric', 'http://med.stanford.edu/labs/eric_sibley/'],
#  ['Sidow, Arend', 'http://mendel.stanford.edu/SidowLab/'],
#  ['Siegel, Robert', 'http://www.stanford.edu/~siegelr/'],
#  ['Sikic, Branimir', 'http://med.stanford.edu/labs/branimir_sikic/'],
#  ['Singh, Upinder', 'http://singhlab.stanford.edu'],
#  ['Snyder, Michael', 'http://snyderlab.stanford.edu'],
#  ['Spielman, Daniel', 'http://rsl.stanford.edu/spielman/'],
#  ['Spudich, James', 'http://spudlab.stanford.edu/'],
#  ['Stanford Magnetic Resonance Laboratory', 'http://cmgm.stanford.edu/SMRL/'],
#  ['Stanford Neuropathology Service', 'http://neuropathology.stanford.edu/'],
#  ['Stanford Psychology and Biobehavioral Sciences Laboratory',
#   'http://psybiobehavior.stanford.edu/'],
#  ['Stanford Renal Pathology Consultation Service\xa0',
#   'http://renalpathology.stanford.edu/'],
#  ['Stanford Research into the Impact of Tobacco Advertising',
#   'http://srita.stanford.edu'],
#  ['Stearns, Tim', 'http://stearnslab.stanford.edu'],
#  ['Steinman, Lawrence', 'http://steinmanlab.stanford.edu/'],
#  ['Steinmetz, Lars',
#   'http://www.stanford.edu/group/steinmetzlab/cgi-bin/wordpress/'],
#  ['Stevenson, David',
#   'http://neonatology.stanford.edu/Research/Neo-Labs.html'],
#  ['Stockdale, Frank', 'http://med.stanford.edu/labs/frank_stockdale/'],
#  ['Straight, Aaron', 'http://straightlab.stanford.edu'],
#  ['Sweet-Cordero, Alejandro', 'http://sweetcorderolab.stanford.edu/'],
#  ['Ta, Christopher',
#   'http://ophthalmology.stanford.edu/research/basic_artificial_cornea.html'],
#  ['Tang, Hua', 'http://med.stanford.edu/tanglab/'],
#  ['Tang, Jean Y.', 'http://jeantanglab.stanford.edu/'],
#  ['Taylor, Craig B.', 'http://bml.stanford.edu/'],
#  ['Teruel, Mary', 'http://teruel.stanford.edu'],
#  ['Theriot, Julie', 'http://cmgm.stanford.edu/theriot/'],
#  ['Toxoplasma Serology Laboratory', 'http://www.pamf.org/Serology'],
#  ['Urban, Alexander Eckehart', 'http://urbanlab.stanford.edu'],
#  ['Utz, PJ', 'http://utzlab.stanford.edu/'],
#  ['Van de Rijn, Matt', 'http://med.stanford.edu/labs/vanderijn-west/'],
#  ['Walbot, Virginia', 'http://www.stanford.edu/~walbot/'],
#  ['Wandless, Thomas', 'http://wandless.stanford.edu'],
#  ['Wang, Denong', 'http://glycome.stanford.edu/'],
#  ['Wang, Xinnan', 'http://xiannanwanglab/stanford.edu'],
#  ['Weiss, Bill', 'http://weis.stanford.edu/'],
#  ['West, Rob', 'http://med.stanford.edu/labs/vanderijn-west/'],
#  ['Weyand, Cornelia M.', 'http://med.stanford.edu/weyand/'],
#  ['Whitlock, James P.', 'http://www.stanford.edu/group/whitlock/'],
#  ['Williams, Leanne', 'http://med.stanford.edu/williamslab/'],
#  ['Willmann, Jürgen', 'http://tmil.stanford.edu/'],
#  ['Winkleby, Marilyn', 'http://winkleby.stanford.edu'],
#  ['Winslow, Monte', 'http://winslowlab.stanford.edu/'],
#  ['Wu, Joseph C.', 'http://wulab.stanford.edu/'],
#  ['Wu, Sean', 'http://seanwulab.stanford.edu'],
#  ['Wyss-Coray, Tony', 'http://www.stanford.edu/group/twclab/cgi-bin/'],
#  ['Xing, Lei', 'http://xinglab.stanford.edu/'],
#  ['Yang, Fan', 'http://fanyanglab.stanford.edu/'],
#  ['Yang, Yanmin', 'http://neurology.stanford.edu/labs/yanglab/'],
#  ['Yang, Yunzhi Peter', 'http://yanglab.stanford.edu/'],
#  ['Yao, Mylene, W.M.', 'http://yaolab.stanford.edu/'],
#  ['Yesavage, Jerome', 'http://www.stanford.edu/~yesavage/'],
#  ['Yock, Paul', 'http://biodesign.stanford.edu/'],
#  ['Zarins, Christopher', 'http://zarinslab.stanford.edu/'],
#  ['Zhou, Wei', 'http://vascular.stanford.edu/research/labs/zhoulab.html'],
#  ['Zuchero, Bradley', 'http://zucherolab.stanford.edu'],
#  ['Academic Affairs', 'http://med.stanford.edu/academicaffairs/'],
#  ['Appointments & Promotions', 'http://facultyappts.stanford.edu/'],
#  ['Association of the Adjunct Clinical Faculty', 'http://aacf.stanford.edu/'],
#  ['Faculty Senate', 'http://med.stanford.edu/senate/'],
#  ['Information Resources & Technology', 'http://med.stanford.edu/irt/'],
#  ['Office of Faculty Development & Diversity',
#   'http://med.stanford.edu/facultydiversity.html'],
#  ['Senior Faculty Transitions', 'http://med.stanford.edu/transitions/'],
#  ['Stanford Faculty Development Center for Medical Teachers',
#   'http://sfdc.stanford.edu/'],
#  ['WellMD', 'http://wellmd.stanford.edu/'],
#  ['Research Management Group', 'http://med.stanford.edu/rmg/'],
#  ['Clinical Trials Administration',
#   'http://med.stanford.edu/rmg/clinical_trial.html'],
#  ['Fellowships', 'http://med.stanford.edu/rmg/fellowships.html'],
#  ['Funding Opportunities', 'http://med.stanford.edu/rmg/funding/'],
#  ['Other Administrative Offices',
#   'http://med.stanford.edu/rmg/resources.html#office'],
#  ['Policies & Compliance',
#   'http://med.stanford.edu/rmg/resources.html#policy'],
#  ['Research Metrics Reports', 'http://med.stanford.edu/rmg/reporting.html'],
#  ['Asian Liver Center', 'http://liver.stanford.edu/'],
#  ['Beckman Center', 'http://beckman.stanford.edu'],
#  ['Canary Center at Stanford', 'http://canarycenter.stanford.edu'],
#  ['Cardiothoracic Surgical Skills & Education Center.',
#   'http://sssec.stanford.edu'],
#  ['Center for Advanced Pediatric & Perinatal Education',
#   'http://cape.lpch.org/'],
#  ['Center for Biomedical Imaging at Stanford', 'http://cbis.stanford.edu/'],
#  ['Center for Clinical Immunology at Stanford', 'http://ccis.stanford.edu'],
#  ['Center for Compassion & Altruism Research and Education',
#   'http://ccare.stanford.edu/'],
#  ['Center for Definitive and Curative Medicine',
#   'http://med.stanford.edu/cdcm.html'],
#  ['Center for Education & Research in Family & Community Medicine',
#   'http://familymedicine.stanford.edu/'],
#  ['Center for Excellence in Pulmonary Biology',
#   'http://breathe.stanford.edu/'],
#  ['Center for Genomics & Personalized Medicine', 'http://scgpm.stanford.edu/'],
#  ['Center for Human Embryonic Stem Cell Research & Education',
#   'http://hesc.stanford.edu/'],
#  ['Center for Immersive & Simulation-based Learning',
#   'http://cisl.stanford.edu/'],
#  ['Center for Innovation in Global Health',
#   'http://globalhealth.stanford.edu/'],
#  ['Center for Integration of Research on Genetics & Ethics',
#   'http://cibsr.stanford.edu/'],
#  ['Center for Interdisciplinary Brain Sciences Research',
#   'http://cibsr.stanford.edu/'],
#  ['Center on Stress & Health', 'http://stresshealthcenter.stanford.edu/'],
#  ['Chase Hand & Upper Limb Center', 'http://handsurgery.stanford.edu/'],
#  ['Chronic Fatigue Syndrome Research Center',
#   'http://med.stanford.edu/sgtc/donation.html'],
#  ['Clinical Excellence Research Center', 'http://cerc.stanford.edu/'],
#  ['Conference Center at Li Ka Shing Center',
#   'http://conferencecenter.stanford.edu/'],
#  ['Conte Center for Neuroscience Research', 'http://conte.stanford.edu/'],
#  ['Cystic Fibrosis Center at Stanford', 'http://cfcenter.stanford.edu/'],
#  ['Freidenrich Center for Translational Research',
#   'http://fctr.stanford.edu/'],
#  ['Genome Technology Center', 'http://med.stanford.edu/sgtc/'],
#  ['Goodman Simulation Center', 'http://goodmancenter.stanford.edu/'],
#  ['March of Dimes Prematurity Research Center',
#   'http://prematurity.stanford.edu'],
#  ['Meta-Research Innovation Center at Stanford\xa0',
#   'http://med.stanford.edu/metrics/'],
#  ['Mood Disorders Center', 'http://med.stanford.edu/mooddisorders.html'],
#  ['National Biocomputation Center', 'http://biocomp.stanford.edu/'],
#  ['Older Adult & Family Center', 'http://med.stanford.edu/oafc/'],
#  ['Pain Management Center', 'http://paincenter.stanford.edu/'],
#  ['Sean N. Parker Center for Allergy Research',
#   'http://med.stanford.edu/allergies'],
#  ['Spectrum Child Health', 'http://spectrumchildhealth.stanford.edu/'],
#  ['Stanford Blood Center', 'http://bloodcenter.stanford.edu'],
#  ['Stanford Center for Biomedical Research', 'http://bmir.stanford.edu/'],
#  ['Stanford Center for Cancer Systems Biology', 'http://ccsb.stanford.edu'],
#  ['Stanford Center for Health Research on Women & Sex Differences in Medicine',
#   'http://wsdm.stanford.edu/'],
#  ['Stanford Center for Inherited Cardiovascular Disease',
#   'http://familyheart.stanford.edu'],
#  ['Stanford Center for Medical Education Research & Innovation',
#   'http://mededresearch.stanford.edu/'],
#  ['Stanford Center for Memory Disorders', 'http://alzheimers.stanford.edu/'],
#  ['Stanford Center for Narcolepsy',
#   'http://med.stanford.edu/psychiatry/narcolepsy/'],
#  ["Stanford Center for Neuroscience in Women's Health",
#   'http://womensneuroscience.stanford.edu/'],
#  ['Stanford Center for Sleep Sciences & Medicine',
#   'http://med.stanford.edu/sleep'],
#  ['Stanford Down Syndrome Research Center', 'http://dsresearch.stanford.edu/'],
#  ['Stanford Geriatric Education Center', 'http://sgec.stanford.edu/'],
#  ['Stanford Myalgic Encephalomyelitis/Chronic Fatigue Syndrome (ME/CFS) Initiative',
#   'http://med.stanford.edu/chronicfatiguesyndrome/'],
#  ['Stanford NHLBI Proteomics Center for Systems Immunology',
#   'http://proteomics.stanford.edu/'],
#  ['Stanford Stroke Center', 'http://strokecenter.stanford.edu/'],
#  ['Stanford-Surgery Policy Improvement Research and Education Center (S-SPIRE)',
#   'http://med.stanford.edu/s-spire.html'],
#  ['Stanford University Center for Biomedical Ethics',
#   'http://bioethics.stanford.edu/'],
#  ['Stanford University Geriatric Education Resource Center\xa0',
#   'http://sugerc.stanford.edu'],
#  ["Stanford/VA Alzheimer's Center", 'http://med.stanford.edu/svalz.html'],
#  ['Surgical Center for Outcomes & Research Evaluation',
#   'http://surgery.stanford.edu/score/'],
#  ['VA Simulation Center', 'http://med.stanford.edu/VAsimulator/'],
#  ['Vera Moulton Wall Center for Pulmonary Vascular Disease',
#   'http://wallcenter.stanford.edu/'],
#  ['3D and Quantitative Imaging Lab', 'http://3dradiology.stanford.edu/'],
#  ['ALS Consortium of Epidemiologic Studies', 'http://aces.stanford.edu/'],
#  ['Arts, Humanities & Medicine Program',
#   'http://bioethics.stanford.edu/arts/'],
#  ['Biomedical Data Science Initiative',
#   'http://med.stanford.edu/bdsi/index.html'],
#  ['Bipolar & Depression Research Program',
#   'http://bipolarresearch.stanford.edu'],
#  ['Body Magnetic Resource Group', 'http://bmrgroup.stanford.edu/'],
#  ['Cognitive Aids in Medicine Group \xa0', 'http://cogaids.stanford.edu'],
#  ['Complementary & Alternative Medicine Program',
#   'http://camps.stanford.edu/'],
#  ['Depression Research Clinic', 'http://med.stanford.edu/depression/'],
#  ['Developmental-Behavioral Pediatrics Research Group',
#   'http://med.stanford.edu/dbpresearch/'],
#  ['Eating Disorders Research Program', 'http://edresearch.stanford.edu/'],
#  ['Human Performance Laboratory',
#   'http://ortho.stanford.edu/humanperformance/'],
#  ['Information Sciences in Imaging at Stanford', 'http://isis.stanford.edu/'],
#  ['Laboratory for the Study of Behavioral Medicine',
#   'http://bml.stanford.edu/'],
#  ['Molecular Imaging Program at Stanford', 'http://mips.stanford.edu/'],
#  ['Network for Translational Research in Optical Imaging',
#   'http://ntroi.stanford.edu/'],
#  ['Neurobehavorial Assessment of the Preterm Infant',
#   'http://med.stanford.edu/NAPI/'],
#  ['Obsessive-Compulsive Disorders Program \n', 'http://ocd.stanford.edu/'],
#  ['Population Health Sciences Initiative', 'http://med.stanford.edu/phs.html'],
#  ['Program on Prevention Outcomes & Practices', 'http://ppop.stanford.edu/'],
#  ['Quality of Care for SMA Patients\xa0', 'http://smascc.stanford.edu/'],
#  ['Radiological Sciences Laboratory', 'http://med.stanford.edu/rsl/'],
#  ['SPARK Program', 'http://sparkmed.stanford.edu/'],
#  ['Stanford AIDS Clinical Trial Unit\xa0', 'http://actu.stanford.edu/'],
#  ['Stanford Anesthesia Informatics & Media Lab', 'http://aim.stanford.edu'],
#  ['Stanford Autopsy Service', 'http://autopsy.stanford.edu/'],
#  ['Stanford Brain Development Project',
#   'http://braindevelopment.stanford.edu/'],
#  ['Stanford Center for Biomedical Ethics', 'http://neuroethics.stanford.edu/'],
#  ['Stanford Early Life Stress Research Program', 'http://elsrp.stanford.edu/'],
#  ['Stanford Functional Genomics Facility', 'http://www.microarray.org/sfgf/'],
#  ['Stanford Initiative to Cure Hearing Loss',
#   'http://hearinglosscure.stanford.edu/'],
#  ['Stanford Internet-based Successful Aging (iSAGE) Project',
#   'http://geriatrics.stanford.edu/'],
#  ['Stanford Multidsciplinary Cutaneous Lymphoma Group',
#   'http://cutaneouslymphoma.stanford.edu/'],
#  ['Stanford Myalgic Encephalomyelitis/Chronic Fatigue Syndrome Initiative',
#   'http://chronicfatigue.stanford.edu/'],
#  ['Stanford Pediatric Bipolar Disorders Program',
#   'http://pediatricbipolar.stanford.edu/'],
#  ['Stanford Program in Epithelial Biology', 'http://epibio.stanford.edu/'],
#  ['Stanford Research into the Impact of Tobacco Advertising',
#   'http://srita.stanford.edu'],
#  ['Stanford-LPCH Vaccine Program', 'http://vaccines.stanford.edu'],
#  ['Stanford/Packard Global Child Health Program',
#   'http://med.stanford.edu/globalpeds/'],
#  ['Systems Neuroscience & Pain Lab', 'http://snapl.stanford.edu/'],
#  ['Translational Research & Applied Medicine Program\xa0',
#   'http://tram.stanford.edu/'],
#  ['Funding Opportunities', 'http://med.stanford.edu/rmg/funding/'],
#  ['Spectrum', 'http://spectrum.stanford.edu/'],
#  ['Freidenrich Center for Translational Research\xa0',
#   'http://fctr.stanford.edu/'],
#  ['Lane Library', 'http://lane.stanford.edu/index.html'],
#  ['Research Technology\xa0', 'http://med.stanford.edu/irt/researchtech/'],
#  ['SPARK Program', 'http://sparkmed.stanford.edu/'],
#  ['Stanford Data Science Resources', 'http://med.stanford.edu/dasher.html'],
#  ['Biodesign Program', 'http://biodesign.stanford.edu'],
#  ['Child Health Research Institute', 'http://chri.stanford.edu/'],
#  ['Stanford Cancer Institute', 'http://cancer.stanford.edu/'],
#  ['Stanford Institute for Stem Cell Biology and Regenerative Medicine',
#   'http://stemcell.stanford.edu/'],
#  ['Stanford Cardiovascular Institute', 'http://cvi.stanford.edu/'],
#  ['Stanford Institute for Immunity, Transplantation and Infection',
#   'http://iti.stanford.edu/'],
#  ['Stanford Biosciences Student Association', 'http://sbsa.stanford.edu/'],
#  ['Biomedical Association for the Interest of Minority Students',
#   'http://bioaims.stanford.edu/'],
#  ['Stanford Medical Student Association', 'http://smsa.stanford.edu/'],
#  ['Stanford University Minority Medical Alliance',
#   'http://summa.stanford.edu/'],
#  ['Asian Pacific American Medical Student Association',
#   'http://apamsa.stanford.edu/'],
#  ['Cardinal Free Clinics', 'http://cfc.stanford.edu/'],
#  ['Cardiothoracic Surgery Residents', 'http://cardiac.stanford.edu/'],
#  ['Cross-disciplinary Healthcare Innovation Partnerships at Stanford',
#   'http://healthcare.stanford.edu/'],
#  ['Dermatology Interest Group', 'http://dig.stanford.edu/'],
#  ['Ears For Peers', 'http://med.stanford.edu/ears4peers/'],
#  ['Emergency Medicine Interest Group', 'http://emig.stanford.edu/'],
#  ['Latino Medical Student Association', 'http://lmsa.stanford.edu/'],
#  ['Lesbian, Gay, Bisexual, and Transgender Medical Education Research Group',
#   'http://med.stanford.edu/lgbt/ '],
#  ['LGBT-Meds', 'http://lgbtmeds.stanford.edu/'],
#  ['Organization for Global Health', 'http://med.stanford.edu/oih/'],
#  ['PALS Program', 'http://med.stanford.edu/pals'],
#  ['Radiology Interest Group at Stanford', 'http://rigs.stanford.edu/'],
#  ['Stanford Society of Physician Scholars', 'http://ssps.stanford.edu/'],
#  ['Surgery Interest Group', 'http://surgeryinterest.stanford.edu/'],
#  ['Vision and Ophthalmology Interest Group', 'http://med.stanford.edu/voig/'],
#  ['Biosciences PhD Program',
#   'http://med.stanford.edu/md/academic-support/academic-advising.html'],
#  ['Alumni Services', 'http://med.stanford.edu/alumni/'],
#  ['Career Center', 'http://med.stanford.edu/careercenter/'],
#  ['Center for Innovation in Global Health',
#   'http://globalhealth.stanford.edu/'],
#  ['Course Catalog', 'http://medcatalog.stanford.edu/'],
#  ['Educational Programs and Services', 'http://med.stanford.edu/eps/'],
#  ['Center of Excellence in Diversity\xa0in Medical Education\xa0',
#   'http://coe.stanford.edu/'],
#  ['Leadership in Health Disparities Program (MD Program)',
#   'http://coe.stanford.edu/med-grad/lhdp.html'],
#  ['Diversity in the PhD Programs',
#   'http://biosciences.stanford.edu/prospective/diversity/index.html'],
#  ['Diversity in Postdoctoral Training',
#   'http://postdocs.stanford.edu/prospects/diversity.html'],
#  ['Summer Undergraduate & Youth Programs',
#   'http://med.stanford.edu/education/summer-outreach.html'],
#  ['Biosciences PhD Program',
#   'http://biosciences.stanford.edu/current/benefits/'],
#  ['MD Program', 'http://med.stanford.edu/md/financial-aid.html'],
#  ['Housing', 'http://www.stanford.edu/dept/rde/cgi-bin/drupal/housing/'],
#  ['Information Resources & Technology', 'http://med.stanford.edu/irt/'],
#  ['Lane Library', 'http://lane.stanford.edu/index.html'],
#  ['Student Commons', 'http://lksc.stanford.edu/students/'],
#  ['Bio-X Program', 'http://biox.stanford.edu/'],
#  ['Privacy Policy', 'http://www.stanford.edu/site/privacy'],
#  ['Terms of Use', 'http://www.stanford.edu/site/terms'],
#  ['Stanford Health Care', 'http://stanfordhealthcare.org'],
#  ["Stanford Children's Health", 'http://www.stanfordchildrens.org'],
#  ["Lucile Packard Children's Hospital Stanford",
#   'http://www.stanfordchildrens.org'],
#  ['University Healthcare Alliance', 'http://universityhealthcarealliance.org']]

# %% [markdown]
# # Pubmed

# %%
import requests

# %%
url_base = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
params = dict(db = 'pubmed', term = 'stanford[ad]Environment+and+Public+Health[mh]', retmode = 'json', retmax = '30')
rsp = requests.get(url_base, params=params)

# %%
print(rsp.url)
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=stanford%5Bad%5DEnvironment%2Band%2BPublic%2BHealth%5Bmh%5D&retmode=json&retmax=30

# %%
len(rsp.json()['esearchresult']['idlist'])
# Out:
# 30

# %%
id_list = rsp.json()['esearchresult']['idlist']

# %%
','.join(id_list)
# Out:
# '30683880,30670697,30667499,30586832,30586505,30586170,30575872,30572165,30562241,30559176,30558033,30547806,30545871,30544793,30522922,30537958,30523329,30531929,30505424,30504286,30501481,30513076,30510157,30509974,30497546,30497450,30496171,30487548,30482205,30481383'

# %%
# fetch one paper
paper_url = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&retmode=xml&id="+','.join(id_list)
paper_rsp = requests.get(paper_url)

# %%
print(paper_url)
# Out:
# http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&retmode=xml&id=30683880,30670697,30667499,30586832,30586505,30586170,30575872,30572165,30562241,30559176,30558033,30547806,30545871,30544793,30522922,30537958,30523329,30531929,30505424,30504286,30501481,30513076,30510157,30509974,30497546,30497450,30496171,30487548,30482205,30481383

# %%
print(paper_rsp)
# Out:
# <Response [200]>

# %%
soup_paper = BeautifulSoup(paper_rsp, 'lxml')
print(soup_paper.find_all('Author'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-360-4112877693fa> in <module>
# ----> 1 soup_paper = BeautifulSoup(paper_rsp, 'lxml')
#       2 print(soup_paper.find_all('Author'))
#
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     243         if hasattr(markup, 'read'):        # It's a file-type object.
#     244             markup = markup.read()
# --> 245         elif len(markup) <= 256 and (
#     246                 (isinstance(markup, bytes) and not b'<' in markup)
#     247                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
from Bio import Entrez
import Bio; print(Bio.__version__)
import pandas as pd
import numpy as np
import re
import time
import math
# Out:
# 1.73

# %%
def search(query, retmax):
    Entrez.email = 'sehjk@stanford.edu'
    handle = Entrez.esearch(db='pubmed', 
                            retmax=retmax,
                            retmode='xml', 
                            term=query)
    results = Entrez.read(handle)
    return results

# %%
def fetch_details(idl):
    if(type(idl) == list):
        ids = ','.join(idl)
    else:
        ids = idl
    Entrez.email = 'sehjk@stanford.edu'
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    results = Entrez.read(handle)
    return results

# %%
meshTerms = ['Environment and Public Health',
            'Health Care Economics and Organizations',
            'Health Care Facilities, Manpower, and Services',
            'Health Care Quality, Access, and Evaluation',
            'Health Services Administration',
            'Population Characteristics']

authors = [] 
pmids = set()
    
for meshTerm in meshTerms:
    
    meshString = meshTerm.replace(" ", "+")
    searchString = 'stanford[ad]'+ meshString + '[mh]'
    print('Submitting {} search to Pubmed'.format(searchString))
    results = search(searchString, retmax = 50000)
    ids = results['IdList']
    
    print('Search returned {} ids for {}'.format(len(ids), meshTerm))
    
    if len(ids) != 0:
        
        if len(ids) >= 9999:
            id_list = np.array_split(np.array(ids), math.ceil(len(ids)/9999))
            
            for mini_list in id_list:
                print('Fetching {} Ids from Pubmed...'.format(len(mini_list)))
                papers = fetch_details(list(mini_list))
                print('Fetched details. Adding to set..')
                for i, paper in enumerate(papers['PubmedArticle']):
                    pmid = str(paper['MedlineCitation']['PMID'])
                    if pmid not in pmids:
                        pmids.add(pmid)
                        author_list = paper['MedlineCitation']['Article']['AuthorList']
                        for author in author_list:
                            if author['AffiliationInfo']: # otherwise typically collectives without affiliation
                                affiliation = author['AffiliationInfo'][0]['Affiliation']
                                if re.match(r'.*\bstanford.*', affiliation, re.IGNORECASE):
                                    #identifier = author['Identifier']
                                    if 'CollectiveName' in author:
                                        name = author['CollectiveName']
                                    else:
                                        lastname = author.get('LastName','NA')
                                        firstname = author.get('ForeName','NA')
                                        initials = author.get('Initials','NA')
                                        name = firstname + " " + lastname
                                    authors.append([pmid, name, affiliation])
                print('Added. Papers analyzed: {0}. {1} Authors detected'.format(len(pmids), len(authors)))
        else:
            id_list = ids
            print('Fetching {} Ids from Pubmed...'.format(len(id_list)))
            papers = fetch_details(list(id_list))
            print('Fetched details. Adding to set..')
            for i, paper in enumerate(papers['PubmedArticle']):
                pmid = str(paper['MedlineCitation']['PMID'])
                if pmid not in pmids:
                    pmids.add(pmid)
                    author_list = paper['MedlineCitation']['Article']['AuthorList']
                    for author in author_list:
                        if author['AffiliationInfo']: # otherwise typically collectives without affiliation
                            affiliation = author['AffiliationInfo'][0]['Affiliation']
                            if re.match(r'.*\bstanford.*', affiliation, re.IGNORECASE):
                                #identifier = author['Identifier']
                                if 'CollectiveName' in author:
                                    name = author['CollectiveName']
                                else:
                                    lastname = author.get('LastName','NA')
                                    firstname = author.get('ForeName','NA')
                                    initials = author.get('Initials','NA')
                                    name = firstname + " " + lastname
                                authors.append([pmid, name, affiliation])
            print('Added. Papers analyzed: {0}. {1} Authors detected'.format(len(pmids), len(authors)))
# Out:
# Submitting stanford[ad]Environment+and+Public+Health[mh] search to Pubmed
# Search returned 27934 ids for Environment and Public Health
# Fetching 9312 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 9312. 25574 Authors detected
# Fetching 9311 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 18623. 39522 Authors detected
# Fetching 9311 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 27934. 48840 Authors detected
# Submitting stanford[ad]Health+Care Economics+and+Organizations[mh] search to Pubmed
# Search returned 4380 ids for Health Care Economics and Organizations
# Fetching 4380 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 29698. 51320 Authors detected
# Submitting stanford[ad]Health+Care Facilities,+Manpower,+and+Services[mh] search to Pubmed
# Search returned 7020 ids for Health Care Facilities, Manpower, and Services
# Fetching 7020 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 31347. 53862 Authors detected
# Submitting stanford[ad]Health+Care Quality,+Access,+and+Evaluation[mh] search to Pubmed
# Search returned 26532 ids for Health Care Quality, Access, and Evaluation
# Fetching 8844 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 31910. 55490 Authors detected
# Fetching 8844 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 32524. 56385 Authors detected
# Fetching 8844 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 33068. 56929 Authors detected
# Submitting stanford[ad]Health+Services+Administration[mh] search to Pubmed
# Search returned 11236 ids for Health Services Administration
# Fetching 5618 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 33245. 57354 Authors detected
# Fetching 5618 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 33455. 57566 Authors detected
# Submitting stanford[ad]Population+Characteristics[mh] search to Pubmed
# Search returned 6377 ids for Population Characteristics
# Fetching 6377 Ids from Pubmed...
# Fetched details. Adding to set..
# Added. Papers analyzed: 33709. 57904 Authors detected

# %%
authors_df = pd.DataFrame(authors)
authors_df.to_csv("authors.csv")
